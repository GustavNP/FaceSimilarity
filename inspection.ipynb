# %%
import pandas as pd

# %%
# inspect_df = pd.read_csv('./similarity_score_files/similarity_scores_Facenet512_yunet_VGGFace-200k-train-431-502.csv', sep=';', header=None)
inspect_df = pd.read_csv('larger_embedding_files\embeddings_Facenet512_yunet_VGGFace-200k-train-51-180.csv', sep=';', header=None)

# %%
pd.options.display.max_colwidth = 200
inspect_df.head()
# Out:
#        0    \
# 0  n000051
# 1  n000051
# 2  n000051
# 3  n000051
# 4  n000051
#
#                                                                                              1    \
# 0  C:/Users/admin/Desktop/aligned-VGGFace200k-folders-51-180/n000051/aligned_n000051-0001_01.jpg
# 1  C:/Users/admin/Desktop/aligned-VGGFace200k-folders-51-180/n000051/aligned_n000051-0002_01.jpg
# 2  C:/Users/admin/Desktop/aligned-VGGFace200k-folders-51-180/n000051/aligned_n000051-0003_02.jpg
# 3  C:/Users/admin/Desktop/aligned-VGGFace200k-folders-51-180/n000051/aligned_n000051-0004_01.jpg
# 4  C:/Users/admin/Desktop/aligned-VGGFace200k-folders-51-180/n000051/aligned_n000051-0005_01.jpg
#
#     2         3         4         5         6         7         8         9    \
# 0  0.94 -0.627524  0.433698 -0.757358 -2.085682 -1.105277 -1.268848 -0.385495
# 1  0.94 -0.624823  0.792234 -0.766112 -1.500815 -0.774436 -0.939639 -0.609051
# ...
